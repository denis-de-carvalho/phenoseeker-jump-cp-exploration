# %% [markdown]
# # Environment setup verification
#
# This notebook just verifies that the Python environment runs correctly and that the basic libraries are accessible. It is the first commit from Colab to the GitHub repo of the Phenoseeker × JUMP-CP exploration project.

# %%
import sys

print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Python executable: /usr/bin/python3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(f"NumPy:      {np.__version__}")
print(f"Pandas:     {pd.__version__}")
print(f"Matplotlib: {plt.matplotlib.__version__}")

print("Environment ready.")
# Out:
# NumPy:      2.0.2
# Pandas:     2.2.2
# Matplotlib: 3.10.0
# Environment ready.
